# %% [markdown]
# <a href="https://colab.research.google.com/github/czkyx/AiLearning/blob/master/Amazon%E6%8E%A8%E8%8D%90%E7%B3%BB%E7%BB%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install recbole
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 31.8 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 58.6 MB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat May  7 09:31:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/share/RecBole-master
# Out:
# /content/drive/Shareddrives/share/RecBole-master

# %% [markdown]
# ## epinions数据集
# user_id:token	item_id:token	rating:float	timestamp:float	price:float

# %%
from recbole.quick_start import run_recbole

run_recbole(model='NGCF', dataset='epinions')
# Out:
# 21 Mar 12:29    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS,full
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ### Caser模型

# %% [markdown]
# epinions数据集

# %%
# !python run_recbole.py --model=Caser  --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 00:56    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS,full
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %%
## 更换metric，行不通
# !python run_recbole.py --model=Caser  --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 01:30    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ### DIN on epinions

# %%
# !python run_recbole.py --model=DIN  --dataset=epinions --config_files=myDIN.yaml
# Out:
# 24 Mar 02:16    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 5
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ### 超参数调整

# %%
# !python run_recbole.py --model=DIN  --dataset=epinions --config_files=myDIN.yaml --params_file=hyper.test
# Out:
# 24 Mar 04:42    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %%
# !python run_recbole.py --model=DIN  --dataset=epinions --config_files=myDIN.yaml --params_file=hyper.test
# Out:
# 24 Mar 04:58    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ValueError: could not convert string to float: 'gift

# %% [markdown]
# 有些数据集内容有问题
# load_col:
#   inter: [user_id, item_id, rating, timestamp,price]
#   去掉了price

# %% [markdown]
# 因为Context类模型不用负采样，因此training_neg_sample_num一定是0

# %% [markdown]
# ### 下面的模型
# load_col:
#     inter: [user_id, item_id, rating]

# %% [markdown]
# ### LR model

# %%
# !python run_recbole.py --model=LR  --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 01:51    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# ...

# %% [markdown]
# ### FM model

# %%
# !python run_recbole.py --model=FM  --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 01:51    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# ...

# %%
# !python run_recbole.py --model=NFM   --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 01:50    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# ...

# %%
# !python run_recbole.py --model=DeepFM --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 01:49    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# ...

# %%
# !python run_recbole.py --model=xDeepFM --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 01:57    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# ...

# %%
# !python run_recbole.py --model=WideDeep --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 02:10    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# ...

# %%
# !python run_recbole.py --model=DCN --dataset=epinions --config_files=myDIN_e.yaml
# Out:
# 24 Mar 02:10    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/epinions
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# ...

# %% [markdown]
# # Amazon_Office_Products

# %% [markdown]
# ## FM

# %%
# !python run_recbole.py --model=FM  --dataset=Amazon_Office_Products --config_files=myDIN_e.yaml
# Out:
# 25 Mar 10:04    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 70
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## NFM

# %%
# !python run_recbole.py --model=NFM   --dataset=Amazon_Office_Products --config_files=myDIN_e.yaml
# Out:
# 24 Mar 02:00    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## DEEPFM

# %%
# !python run_recbole.py --model=DeepFM   --dataset=Amazon_Office_Products --config_files=myDIN_e.yaml
# Out:
# 24 Mar 02:03    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## xDeepFM

# %%
# !python run_recbole.py --model=xDeepFM   --dataset=Amazon_Office_Products --config_files=myDIN_e.yaml
# Out:
# 24 Mar 02:04    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## WideDeep

# %%
# !python run_recbole.py --model=WideDeep --dataset=Amazon_Office_Products --config_files=myDIN_e.yaml
# Out:
# 24 Mar 02:50    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# #### 添加item: [item_id, categories]
# 失败

# %%
# !python run_recbole.py --model=WideDeep --dataset=Amazon_Office_Products --config_files=myDIN.yaml
# Out:
# 24 Mar 02:52    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 5
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## DCN

# %%
# !python run_recbole.py --model=DCN  --dataset=Amazon_Office_Products --config_files=myDIN_e.yaml
# Out:
# 24 Mar 04:32    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## DIN

# %%
# !python run_recbole.py --model=DIN  --dataset=Amazon_Office_Products --config_files=myDIN.yaml
# Out:
# 30 Apr 02:27    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## 本文方法

# %%
# !python run_recbole.py --model=DIEN  --dataset=Amazon_Office_Products --config_files=myDIN.yaml
# Out:
# 29 Apr 03:07    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Office_Products
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# # Amazon_Clothing_Shoes_and_Jewelry
# epoch=10

# %% [markdown]
# ##本文方法

# %%
# !python run_recbole.py --model=DIEN  --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN.yaml
# Out:
# 02 May 13:33    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ## DIN

# %%
# !python run_recbole.py --model=DIN  --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN.yaml
# Out:
# 23 Mar 12:57    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 10
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 5
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %%
# !python run_recbole.py --model=DIN  --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN.yaml
# Out:
# 27 Mar 09:12    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ## FM

# %%
# !python run_recbole.py --model=FM  --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN_e.yaml
# Out:
# 27 Mar 14:28    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ## DEEPFM

# %%
# !python run_recbole.py --model=DeepFM --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN_e.yaml
# Out:
# 27 Mar 14:34    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ## NFM

# %%
# !python run_recbole.py --model=NFM --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN_e.yaml
# Out:
# 27 Mar 14:39    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ## xdeepFM

# %%
# !python run_recbole.py --model=xDeepFM --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN_e.yaml
# Out:
# 27 Mar 14:44    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ## WideDeep

# %%
# !python run_recbole.py --model=WideDeep --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN_e.yaml
# Out:
# 27 Mar 15:05    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# ## DCN

# %%
# !python run_recbole.py --model=DCN  --dataset=Amazon_Clothing_Shoes_and_Jewelry --config_files=myDIN_e.yaml
# Out:
# 07 May 09:38    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Clothing_Shoes_and_Jewelry
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# ...

# %% [markdown]
# # Amazon_Kindle_Store

# %% [markdown]
# ## 本文方法

# %%
# !python run_recbole.py --model=DIEN  --dataset=Amazon_Kindle_Store --config_files=myDIN.yaml
# Out:
# 29 Apr 05:27    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## DIN

# %%
# !python run_recbole.py --model=DIN  --dataset=Amazon_Kindle_Store --config_files=myDIN.yaml
# Out:
# 23 Mar 14:29    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 10
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 5
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## FM

# %%
# !python run_recbole.py --model=FM  --dataset=Amazon_Kindle_Store --config_files=myDIN_e.yaml
# Out:
# 07 May 09:41    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ##DeepFM

# %%
# !python run_recbole.py --model=DeepFM  --dataset=Amazon_Kindle_Store --config_files=myDIN_e.yaml
# Out:
# 07 May 09:45    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## NFM

# %%
# !python run_recbole.py --model=NFM  --dataset=Amazon_Kindle_Store --config_files=myDIN_e.yaml
# Out:
# 07 May 09:48    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## xdeepfm

# %%
# !python run_recbole.py --model=xDeepFM  --dataset=Amazon_Kindle_Store --config_files=myDIN_e.yaml
# Out:
# 07 May 09:51    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## WideDeep

# %%
# !python run_recbole.py --model=WideDeep  --dataset=Amazon_Kindle_Store --config_files=myDIN_e.yaml
# Out:
# 07 May 09:57    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ##DCN

# %%
# !python run_recbole.py --model=DCN  --dataset=Amazon_Kindle_Store --config_files=myDIN_e.yaml
# Out:
# 07 May 10:00    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# # Amazon_Electronics

# %% [markdown]
# ##本文方法

# %%
# !python run_recbole.py --model=DIEN  --dataset=Amazon_Kindle_Store --config_files=myDIN.yaml
# Out:
# 30 Apr 03:04    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Kindle_Store
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %%
##

# %% [markdown]
# ## FM

# %%
# !python run_recbole.py --model=FM  --dataset=Amazon_Electronics --config_files=myDIN_e.yaml
# Out:
# 01 May 11:57    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Electronics
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 20
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ##DeepFM

# %%
# !python run_recbole.py --model=DeepFM  --dataset=Amazon_Electronics --config_files=myDIN_e.yaml
# Out:
# 01 May 11:02    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Electronics
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## NFM

# %%
# !python run_recbole.py --model=NFM  --dataset=Amazon_Electronics --config_files=myDIN_e.yaml
# Out:
# 01 May 12:56    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Electronics
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 20
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## xdeepfm

# %%
# !python run_recbole.py --model=xDeepFM  --dataset=Amazon_Electronics --config_files=myDIN_e.yaml
# Out:
# 01 May 13:49    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Electronics
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 20
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## WideDeep

# %%
# !python run_recbole.py --model=WideDeep  --dataset=Amazon_Electronics --config_files=myDIN_e.yaml
# Out:
# 01 May 15:20    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Electronics
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 20
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 6
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## DIN

# %%
# !python run_recbole.py --model=DIN  --dataset=Amazon_Electronics --config_files=myDIN.yaml
# Out:
# 25 Mar 01:56    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Electronics
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 1
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = False
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = TO_LS, uni100
# group_by_user = True
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...

# %% [markdown]
# ## DCN

# %%
# !python run_recbole.py --model=DCN  --dataset=Amazon_Electronics --config_files=myDIN_e.yaml
# Out:
# 07 May 10:04    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/Amazon_Electronics
# show_progress = True
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 50
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# training_neg_sample_num = 0
# training_neg_sample_distribution = uniform
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# draw_loss_pic = True
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_setting = RO_RS
# group_by_user = False
# split_ratio = [0.8, 0.1, 0.1]
# leave_one_num = 2
# real_time_process = False
# metrics = ['AUC', 'LogLoss']
# topk = [10]
# valid_metric = AUC
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# ...
